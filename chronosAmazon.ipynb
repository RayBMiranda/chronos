# %%
import pandas as pd  # requires: pip install pandas

df = pd.read_csv("water_quality.csv")


import torch
from chronos import ChronosPipeline

pipeline = ChronosPipeline.from_pretrained(
    "amazon/chronos-t5-small",
    device_map="cuda",  # use "cpu" for CPU inference and "mps" for Apple Silicon
    torch_dtype=torch.bfloat16,
)

# context must be either a 1D tensor, a list of 1D tensors,
# or a left-padded 2D tensor with batch as the first dimension
# forecast shape: [num_series, num_samples, prediction_length]
forecast = pipeline.predict(
    context=torch.tensor(df["Turbidity"]),
    prediction_length=12,
    num_samples=20,
)

import matplotlib.pyplot as plt  # requires: pip install matplotlib
import numpy as np

forecast_index = range(len(df), len(df) + 12)
low, median, high = np.quantile(forecast[0].numpy(), [0.1, 0.5, 0.9], axis=0)

plt.figure(figsize=(8, 4))
plt.plot(df["Turbidity"], color="royalblue", label="historical data")
plt.plot(forecast_index, median, color="tomato", label="median forecast")
plt.fill_between(forecast_index, low, high, color="tomato", alpha=0.3, label="80% prediction interval")
plt.legend()
plt.grid()
plt.show()

# %%
# !pip install chronos-forecasting
# Out:
# Collecting chronos-forecasting
#   Downloading chronos_forecasting-1.4.1-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: accelerate<1,>=0.32 in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from chronos-forecasting) (0.34.2)
# Requirement already satisfied: torch<2.6,>=2.0 in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from chronos-forecasting) (2.5.1)
# Requirement already satisfied: transformers<4.48,>=4.30 in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from chronos-forecasting) (4.47.0)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from accelerate<1,>=0.32->chronos-forecasting) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from accelerate<1,>=0.32->chronos-forecasting) (24.2)
# Requirement already satisfied: psutil in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from accelerate<1,>=0.32->chronos-forecasting) (6.1.0)
# Requirement already satisfied: pyyaml in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from accelerate<1,>=0.32->chronos-forecasting) (6.0.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from accelerate<1,>=0.32->chronos-forecasting) (0.26.5)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from accelerate<1,>=0.32->chronos-forecasting) (0.4.5)
# Requirement already satisfied: filelock in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from torch<2.6,>=2.0->chronos-forecasting) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from torch<2.6,>=2.0->chronos-forecasting) (4.12.2)
# Collecting sympy==1.13.1 (from torch<2.6,>=2.0->chronos-forecasting)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from torch<2.6,>=2.0->chronos-forecasting) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from torch<2.6,>=2.0->chronos-forecasting) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from torch<2.6,>=2.0->chronos-forecasting) (2024.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from sympy==1.13.1->torch<2.6,>=2.0->chronos-forecasting) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from transformers<4.48,>=4.30->chronos-forecasting) (2024.11.6)
# Requirement already satisfied: requests in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from transformers<4.48,>=4.30->chronos-forecasting) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from transformers<4.48,>=4.30->chronos-forecasting) (0.21.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from transformers<4.48,>=4.30->chronos-forecasting) (4.67.1)
# Requirement already satisfied: colorama in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from tqdm>=4.27->transformers<4.48,>=4.30->chronos-forecasting) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from jinja2->torch<2.6,>=2.0->chronos-forecasting) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from requests->transformers<4.48,>=4.30->chronos-forecasting) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from requests->transformers<4.48,>=4.30->chronos-forecasting) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from requests->transformers<4.48,>=4.30->chronos-forecasting) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\raybm\miniconda3\envs\agpu\lib\site-packages (from requests->transformers<4.48,>=4.30->chronos-forecasting) (2024.8.30)
# Downloading chronos_forecasting-1.4.1-py3-none-any.whl (28 kB)
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ------------------------------------- -- 5.8/6.2 MB 29.4 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 29.2 MB/s eta 0:00:00
# Installing collected packages: sympy, chronos-forecasting
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.3
#     Uninstalling sympy-1.13.3:
#       Successfully uninstalled sympy-1.13.3
# Successfully installed chronos-forecasting-1.4.1 sympy-1.13.1
